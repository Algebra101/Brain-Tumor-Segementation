# %%
# !pip install ultralytics roboflow
from ultralytics import YOLO
from roboflow import Roboflow
#Api to the Dataset
rf = Roboflow(api_key="JZYnqR9HmLD000Lip7vh")
project = rf.workspace("brain-tumor-detection-wsera").project("tumor-detection-ko5jp")
version = project.version(8)


#Load Model
model = YOLO("yolo11n.pt")

#Train Model
train_results = model.train(
    data="https://universe.roboflow.com/ds/K764Jv4Jnk?key=lad0tDWoNc", 
    epochs=20, # No of training epochs
    imgsz=640, # Training img size
    device=0
)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 18.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.3/85.3 kB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 39.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 114.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 31.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 76.8 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
    
#Load Model
model = YOLO("/kaggle/working/runs/detect/train/weights/best.pt")

#Perform Object detection on an image
results = model("/kaggle/working/datasets/K764Jv4Jnk/test/images/meningioma_1022_jpg.rf.a3ae957a204e1f240de0d48f7c95c0aa.jpg", save =True)
results[0].show()
# Out:
# image 1/1 /kaggle/working/datasets/K764Jv4Jnk/test/images/meningioma_1022_jpg.rf.a3ae957a204e1f240de0d48f7c95c0aa.jpg: 640x640 1 meningioma, 8.6ms
# Speed: 1.6ms preprocess, 8.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# <PIL.Image.Image image mode=RGB size=640x640>

# %%
#Load Model
model = YOLO("/kaggle/working/runs/detect/train/weights/best.pt")

#Perform Object detection on an image
results = model("/kaggle/working/datasets/K764Jv4Jnk/test/images", save =True)
# Out:
# image 1/191 /kaggle/working/datasets/K764Jv4Jnk/test/images/glioma_1025_jpg.rf.16f677de0fc84afa6b702f2fb8bdb3c2.jpg: 640x640 1 glioma, 8.3ms
# image 2/191 /kaggle/working/datasets/K764Jv4Jnk/test/images/glioma_1128_jpg.rf.e50d9e41b37fb138368e116b69077ff7.jpg: 640x640 1 glioma, 1 pituitary, 8.1ms
# image 3/191 /kaggle/working/datasets/K764Jv4Jnk/test/images/glioma_1166_jpg.rf.493c4f22cb16b11580eabec42f51c3de.jpg: 640x640 1 glioma, 1 meningioma, 8.0ms
# image 4/191 /kaggle/working/datasets/K764Jv4Jnk/test/images/glioma_1246_jpg.rf.af4ca1f2e92bf1e7df0360136f128877.jpg: 640x640 2 gliomas, 1 meningioma, 8.2ms
# image 5/191 /kaggle/working/datasets/K764Jv4Jnk/test/images/glioma_20_jpg.rf.8fdf825f9ca269bc07429aee7781e8d9.jpg: 640x640 1 glioma, 8.1ms
# image 6/191 /kaggle/working/datasets/K764Jv4Jnk/test/images/glioma_271_jpg.rf.6bc0439160ce05a380aa64a2dbac9a3c.jpg: 640x640 1 glioma, 8.7ms
# ...

# %%
from ultralytics import YOLO
    
#Load Model
model = YOLO("/kaggle/working/runs/detect/train/weights/best.pt") #Pretrained YOLO11n model

#Run batched inference on a list of  images
results = model("/kaggle/working/datasets/K764Jv4Jnk/test/images/meningioma_1022_jpg.rf.a3ae957a204e1f240de0d48f7c95c0aa.jpg") #return a list of results objects

#process results list
for result in results:
    boxes = result.boxes  #Boxes object for bounding box outputs
    print(boxes)
# Out:
# image 1/1 /kaggle/working/datasets/K764Jv4Jnk/test/images/meningioma_1022_jpg.rf.a3ae957a204e1f240de0d48f7c95c0aa.jpg: 640x640 1 meningioma, 8.3ms
# Speed: 1.4ms preprocess, 8.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.], device='cuda:0')
# conf: tensor([0.9485], device='cuda:0')
# data: tensor([[230.0298, 173.5572, 350.6398, 291.3755,   0.9485,   2.0000]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (640, 640)
# shape: torch.Size([1, 6])
# xywh: tensor([[290.3348, 232.4663, 120.6100, 117.8183]], device='cuda:0')
# xywhn: tensor([[0.4536, 0.3632, 0.1885, 0.1841]], device='cuda:0')
# xyxy: tensor([[230.0298, 173.5572, 350.6398, 291.3755]], device='cuda:0')
# xyxyn: tensor([[0.3594, 0.2712, 0.5479, 0.4553]], device='cuda:0')

# %%
from ultralytics import YOLO
from ultralytics import SAM
    
#Load the YOLO11 Model
model = YOLO("/kaggle/working/runs/detect/train/weights/best.pt") #Pretrained YOLO11n model

#Run batched inference on a list of  images
results = model("/kaggle/working/datasets/K764Jv4Jnk/test/images/meningioma_1022_jpg.rf.a3ae957a204e1f240de0d48f7c95c0aa.jpg") #return a list of results objects

#process results list
for result in results:
    boxes = result.boxes  #Boxes object for bounding box outputs
    print(boxes)


#Load the SAM model
sam_model = SAM("sam2_b.pt")

#instant segmentation of the outputs of yolo11n model
for result in results:
    class_ids = result.boxes.cls.int().tolist()  #noqa
    if len(class_ids):
        boxes = result.boxes.xyxy   #Boxes object for bbox otputs
        sam_results = sam_model(result.orig_img, bboxes=boxes, verbose=False,save=True,device=0)
# Out:
# image 1/1 /kaggle/working/datasets/K764Jv4Jnk/test/images/meningioma_1022_jpg.rf.a3ae957a204e1f240de0d48f7c95c0aa.jpg: 640x640 1 meningioma, 8.4ms
# Speed: 1.6ms preprocess, 8.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.], device='cuda:0')
# conf: tensor([0.9485], device='cuda:0')
# data: tensor([[230.0298, 173.5572, 350.6398, 291.3755,   0.9485,   2.0000]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (640, 640)
# shape: torch.Size([1, 6])
# xywh: tensor([[290.3348, 232.4663, 120.6100, 117.8183]], device='cuda:0')
# xywhn: tensor([[0.4536, 0.3632, 0.1885, 0.1841]], device='cuda:0')
# xyxy: tensor([[230.0298, 173.5572, 350.6398, 291.3755]], device='cuda:0')
# xyxyn: tensor([[0.3594, 0.2712, 0.5479, 0.4553]], device='cuda:0')
# ...
# 100%|██████████| 154M/154M [00:00<00:00, 281MB/s]
# Results saved to runs/segment/predict
